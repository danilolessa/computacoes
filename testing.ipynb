# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sympy import *

# %%
N = int(1e4)
x = np.linspace(0, 1, N)
y = x ** 2 + 3 * x + np.random.randn()

# %%
plt.plot(x, y, '.')
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
def f(p, pk, n):
    if (type(n) is not int) or n < 1:
        return p
    tp = p + pk - p * pk
    if n == 1:
        return tp
    return f(tp, pk, n - 1)
f = np.vectorize(f)

# %%
p = 0.01
n = np.arange(0, 19)
y = f(p, p, n)
x = n + 1
plt.plot(x, y, '-*')
plt.xlabel("Anos")
plt.ylabel("Probabilidade")
plt.ylim((0, 1))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-a857cca5fbb8> in <module>()
#       1 p = 0.01
#       2 n = np.arange(0, 19)
# ----> 3 y = f(p, p, n)
#       4 x = n + 1
#       5 plt.plot(x, y, '-*')
#
# NameError: name 'f' is not defined

# %%
x, g, A = symbols("x g A", real=True)
solve([g <= 1, g >= 0], g)
# Out:
# And(0 <= g, g <= 1)

# %%
expr = x / (1 - exp(-2*x / ((1 - x) * (1 - g)))) - A

# %%
limit(expr, x, 0)
# Out:
# -A - g/2 + 1/2

# %%
tim = (raw.time - raw.time[0]) / (60 * 60)
T1 = raw.T1 - 273.15
T2 = raw.T2 - 273.15
plt.plot(tim, T1, 'b-')
plt.plot(tim, T2, 'r-')
plt.show()

# %%
plt.plot(tim, raw.humidity, 'b-')
plt.show()

# %%
plt.plot(tim, raw.pressure, '-g')
plt.show()
