# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np

# %%
N = int(1e4)
x = np.linspace(0, 1, N)
y = x ** 2 + 3 * x + np.random.randn()

# %%
plt.plot(x, y, '.')
plt.show()
# Out:
# <img src="data:image/png;base64,...">
