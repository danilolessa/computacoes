# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np

# %%
file = "cartao.tsv"
raw = pd.read_csv(file, sep="\t", parse_dates=[0], infer_datetime_format=True)
raw = raw[raw.amount > 0]
raw = raw[raw.amount < 400]

# %%
plt.plot(raw.date, raw.amount, '.')
plt.show()

# %%
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(raw.datevalue, raw.amount)

plt.plot(raw.datevalue, intercept + slope * raw.datevalue - stderr, 'r--')
plt.plot(raw.datevalue, intercept + slope * raw.datevalue, 'r-')
plt.plot(raw.datevalue, intercept + slope * raw.datevalue + stderr, 'r--')
plt.plot(raw.datevalue, raw.amount, 'b.')

# %%
plt.hist(raw.amount, bins=10)
plt.show()

# %%
np.mean(raw.amount)
# Out:
# 24.24610478359909
