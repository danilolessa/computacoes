# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
raw = pd.read_excel("mat220-provas.xls")

# %%
plt.hist(raw.P1[~np.isnan(raw.P1)], bins = 5, range=(0, 10))
plt.show()

# %%
np.mean(raw.P1)
# Out:
# 5.6171428571428565

# %%
plt.hist(raw.P2[~np.isnan(raw.P2)], bins = 5, range=(0, 10))
plt.show()

# %%
np.mean(raw.P2)
# Out:
# 4.9223880597014924

# %%
np.std(raw.P2)

# %%
len(raw.P1[raw.P1 > 5]) / len(raw.P1)
# Out:
# 0.43333333333333335

# %%
len(raw.P1[raw.P1 > 5.6]) / len(raw.P1)
# Out:
# 0.36666666666666664

# %%
((5 * 6) - 5.6 - 2 * 7.8) / 3
# Out:
# 2.933333333333333

# %%
np1 = 6.3
np2 = 4.3
((5 * 6) - np1 - 2 * np2) / 3
# Out:
# 5.033333333333333
