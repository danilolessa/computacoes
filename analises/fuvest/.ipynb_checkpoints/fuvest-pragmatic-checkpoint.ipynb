# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as st

# %%
em1 = "Onde você realizou seus estudos de ensino médio?"
em2 = "Onde você cursou o ensino médio?"

base_path = "dados/"

# %%
def filter_fase_tipo(string, fase, tipo):
    sfase = string[5:][:1]
    stipo = string[7:][:1]
    if sfase == str(fase) and stipo == str(tipo):
        return True
    else:
        return False

# %%
#Localização dos arquivos
dir_files = os.listdir(base_path)
quest_files = [base_path + file for file in dir_files if len(file[:-5]) == 4]
quest_files = sorted(quest_files)
dat_files = [base_path + file for file in dir_files if len(file[:-5]) == 8]

inscritos_files = sorted([file for file in dat_files if filter_fase_tipo(os.path.basename(file), 1, 2)])
matriculados_files = sorted([file for file in dat_files if filter_fase_tipo(os.path.basename(file), 4, 2)])

# %%
n = 12
aa = pd.read_json(quest_files[n])
bb = pd.read_json(inscritos_files[n])
ind = aa[aa[3].str.contains("sua cor")][0].values[0] - 1
aa
# Out:
#     0   1   2                                                  3   \
# 0    1   2   1                                 Qual é o seu sexo?
# 1    2   4   2                         Qual é o seu estado civil?
# 2    3   5   3                          Qual é a sua cor ou raça?
# 3    4   6   4             Onde você cursou o ensino fundamental?
# 4    5   6   5                   Onde você cursou o ensino médio?
# 5    6   6   6  Que tipo de curso de ensino médio você conclui...
# 6    7   6   7           Em que turno você cursou o ensino médio?
# 7    8   5   8  Você frequenta ou frequentou cursinho pré-vest...
# 8    9   5   9  Você já iniciou ou está frequentando algum cur...
# 9   10   9  10  Somando a sua renda com a renda das pessoas qu...
# 10  11   6  11  Quantas pessoas da família vivem da renda indi...
# 11  12   4  12  Quantas pessoas contribuem para a obtenção des...
# 12  13   9  13  Qual é o nível de instrução de seu pai ou resp...
# 13  14   9  14  Qual é o nível de instrução de sua mãe ou resp...
# 14  15   4  15           Você exerce alguma atividade remunerada?
# 15  16   8  16  Onde você acessa a Internet com maior frequência?
# 16  17  11  17  Quanto à manutenção mensal de sua família, ass...
# 17  18   5  18  Indique a situação do imóvel em que sua famíli...
# 18  19   7  19  Como pretende se manter durante seus estudos u...
# 19  20   6  20                Quantos carros existem em sua casa?
# 20  21   5  21     Quantos microcomputadores existem em sua casa?
# 21  22   2  22  No ano passado, você se inscreveu como "treine...
# 22  23   5  23  Além do vestibular da FUVEST, você pretende se...
# 23  24   5  24  Quantos vestibulares você já prestou na FUVEST...
# 24  25   6  25  Em algum dos vestibulares que você já prestou ...
# 25  26   2  -4                            Você optou pelo PASUSP?
# 26  27   2  -3        Você está participando do processo INCLUSP?
# 27  28   8  -2                      Qual sua idade em 31/12/2012?
#
#                                           4   \
# 0                                 Masculino.
# 1                                  Solteiro.
# 2                                    Branca.
# 3                    Todo em escola pública.
# 4                    Todo em escola pública.
# 5                        Ensino médio comum.
# 6             Diurno (só manhã ou só tarde).
# 7                                       Não.
# 8                                       Não.
# 9                          Inferior a 01 SM.
# 10                                      Uma.
# 11                                      Uma.
# 12                              Não estudou.
# 13                              Não estudou.
# 14                                      Não.
# 15                                  Em casa.
# 16  Proprietário de empresa grande ou média.
# 17                         Próprio, quitado.
# 18            Somente com recursos dos pais.
# 19                                   Nenhum.
# 20                                   Nenhum.
# 21                                      Sim.
# 22                               Da UNICAMP.
# 23                                   Nenhum.
# 24                                      Não.
# 25                                       Sim
# 26                                       Sim
# 27                               Até 16 anos
#
#                                                    5   \
# 0                                           Feminino.
# 1                            Em união estável/casado.
# 2                                              Preta.
# 3                          Todo em escola particular.
# 4                          Todo em escola particular.
# 5   Curso técnico (Industrial, Eletrônica, Química...
# 6                    Diurno integral (manhã e tarde).
# 7                       Sim, intensivo de seis meses.
# 8                               Sim, mas o abandonei.
# 9                                   Entre 01 e 02 SM.
# 10                                              Duas.
# 11                                              Duas.
# 12                     Ensino fundamental incompleto.
# 13                     Ensino fundamental incompleto.
# 14                         Sim, em trabalho eventual.
# 15                                 Em casa de amigos.
# 16           Proprietário de pequena ou microempresa.
# 17  Cedido por instituição/empresa/parentes/conhec...
# 18  Trabalhando, mas contando, para o essencial, c...
# 19                                                Um.
# 20                                                Um.
# 21                                               Não.
# 22                                          Da UNESP.
# 23                                                Um.
# 24                  Sim, mas não efetuei a matrícula.
# 25                                                Não
# 26                                                Não
# 27                                            17 anos
#
#                                                    6   \
# 0                                                None
# 1                 Desquitado, separado ou divorciado.
# 2                                              Parda.
# 3                      Maior parte em escola pública.
# 4                      Maior parte em escola pública.
# 5              Curso para magistério (antigo Normal).
# 6                                            Noturno.
# 7                                Sim, durante um ano.
# 8   Sim, mas irei abandoná-lo se passar neste vest...
# 9                                   Entre 02 e 03 SM.
# 10                                              Três.
# 11                                              Três.
# 12                       Ensino fundamental completo.
# 13                       Ensino fundamental completo.
# 14               Sim, regularmente, em tempo parcial.
# 15                                       No trabalho.
# 16  Funcionário público da administração direta ou...
# 17               Próprio, com financiamento em curso.
# 18  Trabalhando para participar do rateio das desp...
# 19                                              Dois.
# 20                                              Dois.
# 21                                               None
# 22                             Da UNICAMP e da UNESP.
# 23                                              Dois.
# 24        Efetuei a matrícula, mas abandonei o curso.
# 25                                               None
# 26                                               None
# 27                                            18 anos
#
#                                                    7   \
# 0                                                None
# 1                                              Viúvo.
# 2                                            Amarela.
# 3                   Maior parte em escola particular.
# 4                   Maior parte em escola particular.
# 5                 Educação de jovens e adultos (EJA).
# 6                              Maior parte no diurno.
# 7     Sim, já é o segundo ano que frequento cursinho.
# 8       Sim, estou cursando e pretendo fazer os dois.
# 9                                   Entre 03 e 05 SM.
# 10                                            Quatro.
# 11                                    Quatro ou mais.
# 12                           Ensino médio incompleto.
# 13                           Ensino médio incompleto.
# 14              Sim, regularmente, em tempo integral.
# 15                          Na escola ou no cursinho.
# 16  Profissional liberal, trabalhando por conta pr...
# 17                                           Alugado.
# 18  Por conta própria, com recursos oriundos de tr...
# 19                                              Três.
# 20                                              Três.
# 21                                               None
# 22  De outras universidades, mas não no da UNICAMP...
# 23                                              Três.
# 24  Ainda estou fazendo o curso no qual me matricu...
# 25                                               None
# 26                                               None
# 27                                            19 anos
#
#                                                    8   \
# 0                                                None
# 1                                                None
# 2                                           Indígena.
# 3                                        No exterior.
# 4                                        No exterior.
# 5             Certificação do Ensino Médio pelo ENEM.
# 6                             Maior parte no noturno.
# 7             Sim, já frequento há mais de dois anos.
# 8                                Sim, e já o concluí.
# 9                                   Entre 05 e 07 SM.
# 10                                             Cinco.
# 11                                               None
# 12                             Ensino médio completo.
# 13                             Ensino médio completo.
# 14                                               None
# 15                             No centro comunitário.
# 16         Funcionário de empresa privada ou estatal.
# 17  Próprio, construído em terreno sem regularização.
# 18         Com bolsa de estudos ou crédito educativo.
# 19                                            Quatro.
# 20                                    Quatro ou mais.
# 21                                               None
# 22  Não pretende inscrever-se em nenhum outro vest...
# 23                                    Quatro ou mais.
# 24          Já concluí o curso no qual me matriculei.
# 25                                               None
# 26                                               None
# 27                                            20 anos
#
#                                                    9   \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                  Em outra situação.
# 4                                  Em outra situação.
# 5                                              Outro.
# 6                                        Outro turno.
# 7                                                None
# 8                                                None
# 9                                   Entre 07 e 10 SM.
# 10                                      Seis ou mais.
# 11                                               None
# 12                        Ensino superior incompleto.
# 13                        Ensino superior incompleto.
# 14                                               None
# 15                                     Em LAN houses.
# 16  Capitalista (vive de rendimentos de aluguéis e...
# 17                                               None
# 18  Com bolsa ou crédito educativo, trabalhando e ...
# 19                                     Cinco ou mais.
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24         Nunca prestei nenhum vestibular na FUVEST.
# 25                                               None
# 26                                               None
# 27                                            21 anos
#
#                             10  \
# 0                         None
# 1                         None
# 2                         None
# 3                         None
# 4                         None
# 5                         None
# 6                         None
# 7                         None
# 8                         None
# 9            Entre 10 e 15 SM.
# 10                        None
# 11                        None
# 12   Ensino superior completo.
# 13   Ensino superior completo.
# 14                        None
# 15             Em outro local.
# 16  Aposentado ou pensionista.
# 17                        None
# 18                     Outros.
# 19                        None
# 20                        None
# 21                        None
# 22                        None
# 23                        None
# 24                        None
# 25                        None
# 26                        None
# 27             de 22 a 25 anos
#
#                                                    11  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                   Entre 15 e 20 SM.
# 10                                               None
# 11                                               None
# 12                          Pós-Graduação incompleta.
# 13                          Pós-graduação incompleta.
# 14                                               None
# 15                                        Não acesso.
# 16  No momento, não exerce atividade remunerada e ...
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                   Acima de 25 anos
#
#                                                    12  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                     Acima de 20 SM.
# 10                                               None
# 11                                               None
# 12                            Pós-graduação completa.
# 13                            Pós-graduação completa.
# 14                                               None
# 15                                               None
# 16  Trabalho eventual (exercício do trabalho sem a...
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
#
#                                                   13      14
# 0                                               None    None
# 1                                               None    None
# 2                                               None    None
# 3                                               None    None
# 4                                               None    None
# 5                                               None    None
# 6                                               None    None
# 7                                               None    None
# 8                                               None    None
# 9                                               None    None
# 10                                              None    None
# 11                                              None    None
# 12                                              None    None
# 13                                              None    None
# 14                                              None    None
# 15                                              None    None
# 16  Atividade agropecuária (meeiros, arrendatários).  Outra.
# 17                                              None    None
# 18                                              None    None
# 19                                              None    None
# 20                                              None    None
# 21                                              None    None
# 22                                              None    None
# 23                                              None    None
# 24                                              None    None
# 25                                              None    None
# 26                                              None    None
# 27                                              None    None

# %%
def gogo_dataset(files):
    output = {"ano": [], "cor": [], "escola": [], "renda": []}

    for i in range(len(quest_files)):
        ano = os.path.basename(quest_files[i])[:4]
        ano = int(ano)
        quest = pd.read_json(quest_files[i])

        cor_index = quest[quest[3].str.contains("sua cor")][0].values[0] - 1
        renda_index = quest[quest[3].str.contains("renda familiar mensal")][0].values[0] - 1

        magic = 2

        if ano == 2006:
            magic = 3
        elif 2007 <= ano <= 2009:
            magic = 4
        elif 2010 <= ano <= 2013:
            magic = 5

        if int(ano) <= 2012:
            escola_index = quest[quest[3].str.contains(em1)][0].values[0] - 1
        else:
            escola_index = quest[quest[3].str.contains(em2)][0].values[0] - 1

        ds = pd.read_json(files[i])
        ds = ds[6].tail(magic).head(1).values[0]
        resp_cor = ds[cor_index]
        resp_escola = ds[escola_index]
        resp_renda = ds[renda_index]
        output["ano"].append(ano)
        output["cor"].append(resp_cor)
        output["escola"].append(resp_escola)
        output["renda"].append(resp_renda)
        
    return output

# %%
res_insc = gogo_dataset(inscritos_files)
res_matr = gogo_dataset(matriculados_files)

# %%
res_insc["cor"]
# Out:
# [[120498, 93197, 3186, 9014, 12374, 584],
#  [122806, 94520, 3601, 9250, 13234, 648],
#  [134793, 102628, 4504, 9574, 15966, 784],
#  [135851, 99583, 5201, 9358, 19152, 732],
#  [136789, 95393, 6747, 8671, 23975, 792],
#  [152927, 104961, 8377, 8823, 28252, 883],
#  [125998, 90306, 6162, 7883, 19974, 571],
#  [123476, 90195, 5544, 7651, 18531, 464],
#  [122472, 91280, 4886, 7494, 17287, 350],
#  [113793, 87808, 4019, 7113, 14427, 412],
#  [122185, 94225, 4523, 7304, 15752, 380],
#  [128101, 97568, 5216, 7035, 17895, 387],
#  [138094, 104057, 5917, 20806, 6998, 316],
#  [147641, 107864, 6866, 25342, 7145, 416],
#  [126978, 93516, 5452, 21059, 6511, 439],
#  [128584, 93261, 5983, 22532, 6448, 360]]

# %%
x = []
y_geral = []
y_branco = []
y_pardo = []
y_preto = []
y_indio = []
y_amarelo = []

y_renda = []
for i in range(len(res_insc["cor"])):
    x.append(res_insc["ano"][i])
    y_geral.append(res_matr["cor"][i][0] / res_insc["cor"][i][0])
    y_branco.append(res_matr["cor"][i][1] / res_insc["cor"][i][1])
    
    if res_insc["ano"][i] > 2012:
        y_pardo.append(res_matr["cor"][i][3] / res_insc["cor"][i][3])
        y_amarelo.append(res_matr["cor"][i][4] / res_insc["cor"][i][4])
    else:
        y_pardo.append(res_matr["cor"][i][4] / res_insc["cor"][i][4])
        y_amarelo.append(res_matr["cor"][i][3] / res_insc["cor"][i][3])
    y_preto.append(res_matr["cor"][i][2] / res_insc["cor"][i][2])

    y_indio.append(res_matr["cor"][i][5] / res_insc["cor"][i][5])
x = np.array(x)

# %%
ax = plt.subplot(111)


def plot_generic(x, y, label, color):
    x = np.array(x)
    y = np.array(y)
    xx = x - np.min(x)
    r = st.linregress(xx, y)
    #plt.plot(x, x * r.slope + r.intercept, '--', color=color)
    plt.plot(x, y, '-o', color=color, label=label)
    print("%s - Slope: %s, Intercept: %s, P: %s" % (label, r.slope, r.intercept, r.pvalue))

plot_generic(x, y_geral, "Todos", "green")
plot_generic(x, y_branco, "Brancos", "blue")
plot_generic(x, y_preto, "Pretos", "black")
plot_generic(x, y_pardo, "Pardos", "orange")
plot_generic(x, y_amarelo, "Amarelos", "yellow")
plot_generic(x, y_indio, "Indígenas", "red")

ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1),
          ncol=3, fancybox=True, shadow=True)
plt.ylim(0, 0.2)
plt.title("Evolução da fração de aprovados para cada declaração de cor na FUVEST")
plt.xlabel("Ano")
plt.ylabel("$\\frac{Matriculados}{Inscritos}$")
plt.xlim(2001, 2016)
plt.show()
# Out:
# Todos - Slope: 0.00151272305332, Intercept: 0.065473068982, P: 0.00179708800456
# Brancos - Slope: 0.00147138690879, Intercept: 0.0690220318707, P: 0.00170757277858
# Pretos - Slope: 0.00263305941676, Intercept: 0.0236600284088, P: 0.000137709588298
# Pardos - Slope: 0.00219295739891, Intercept: 0.040882531744, P: 0.000356429856322
# Amarelos - Slope: 0.00110566287958, Intercept: 0.10143410032, P: 0.074314753429
# Indígenas - Slope: 0.00127149473494, Intercept: 0.0464582906731, P: 0.0624599316362
