# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
N = int(1e2)
x = np.linspace(-3, 3, N)
y = np.linspace(-1, 1, N)
dat = np.zeros((N, N), dtype=np.complex64)
f = lambda z: 1 / np.power((z - 1), 2)

for i in range(0, N):
    for j in range(0, N):
        z = x[i] + 1j*y[j]
        dat[i, j] = f(z)

# %%
plt.matshow(np.imag(dat))
plt.colorbar()
plt.show()

# %%
def f(z):
    return np.pi * 1j / 2 * (2 * z + 3) * (-np.sin(z ** 2 + 3 * z - 1))

# %%
f(-3/4)
# Out:
# 1.0335378780350548j

# %%
z0 = -3/4

# %%
np.sin(z0 ** 2 + 3 * z0 - 1)
# Out:
# -0.43864709909863309

# %%
N = int(1e3)
ar = -1 * np.pi
br = 1 * np.pi
ai = -2 * np.pi
bi = 2 * np.pi

(x, y) = np.mgrid[ar:br:1j*N, ai:bi:1j*N]
z = x + 1j * y

func = lambda z: np.tanh(z / 2)
out = func(z)

# %%
plt.matshow(np.abs(out))
xticks = np.linspace(ar, br, 3)
yticks = np.linspace(ai, bi, 3)
plt.clim(-10, 10)
plt.colorbar()
plt.show()
