# %%
# %matplotlib notebook
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
raw = pd.read_csv("modis.csv")

# %%
dat = raw[raw.ScanTime > 0]
#dat = dat[dat.CloudFraction < 100]
t = (dat.ScanTime - np.min(dat.ScanTime)) / (60 * 60 * 24 * 365)

# %%
tmin = np.min(t)
tmax = np.max(t)
ttot = tmax - tmin
dt = 1 / 12
n = int(ttot / dt)
tt = []
med = []
mean = []
qtd = []
for i in range(0, n):
    tt.append(i)
    datt = dat[((i * dt) < t) & (t < (i + 1) * dt)]
    qtd.append(len(datt))
    med.append(np.median(datt.CloudFraction))
    mean.append(np.median(datt.CloudFraction))

# %%
plt.bar(tt, mean)
plt.title("Cloud Fraction em Manacapuru (MYD06_L2)")
plt.xticks(np.arange(26))
plt.ylabel("Cloud Fraction médio")
plt.xlabel("Tempo (meses) após inicio do projeto")
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
plt.plot(t, dat.CloudFraction, ',')
plt.show()
# Out:
# <img src="data:image/png;base64,...">
