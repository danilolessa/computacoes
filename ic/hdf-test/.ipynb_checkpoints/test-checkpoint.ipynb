# %%
# %matplotlib inline
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import numpy as np
from inspect import *
from pyhdf.SD import *

# %%
path = "test.hdf"

# %%
sd = SD(path)

# %%
lat = sd.select("Latitude")[:]
lon = sd.select("Longitude")[:]
loc = (lon, lat)

d1 = sd.select('Surface_Pressure')
d2 = sd.select('Cloud_Fraction')
d3 = sd.select('Brightness_Temperature')

# %%
d1.getdatastrs()
# Out:
# ('Surface Pressure from Ancillary Data', 'hPa', '', '')

# %%
m = Basemap(projection='ortho',lon_0=np.min(lon),lat_0=np.min(lat),resolution='l')
x, y = m(lon,lat)
m.drawmapboundary()

m.drawcoastlines()
m.contourf(x,y,d1[:])
plt.colorbar()
plt.show()
