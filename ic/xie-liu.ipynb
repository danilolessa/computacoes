# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")

# %%
raw = pd.read_pickle("CF-XL.pkl")
dat = raw[raw.CloudFraction <= 1]
#dat = dat[dat.CloudFractionCorrected <= 1]

# %%
plt.plot(dat.Time / (60 * 60), dat.CloudFractionCorrected, ',')
plt.show()

# %%
plt.hist(dat.CloudFraction, range=(0, 1))
plt.show()
