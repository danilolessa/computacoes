# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")

# %%
len(raw[raw.XL_CloudFraction > 1]) / len(raw)
# Out:
# 0.011400462962962963

# %%
dat = pd.read_pickle("CF-XL.pkl")
#dat = raw[raw.XL_CloudFraction <= 1]
#dat = dat[dat.CloudFractionCorrected <= 1]

# %%
np.max(dat.XL_CloudFraction)
# Out:
# 1.0

# %%
plt.plot(dat.Time / (60 * 60), dat.XL_CloudFractionCorrected, ',')
plt.show()

# %%
plt.hist(dat.CloudFraction_Shortwave, range=(0, 1))
plt.show()

# %%
np.max(dat.CloudFraction_Shortwave)
# Out:
# masked

# %%
np.std(dat.XL_CloudFraction)
# Out:
# 17332769247.003937
