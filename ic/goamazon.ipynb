# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import time

# %%
cloud_file = "dados/goamazon-radiometro/danilo-allclouds.csv"
dat = pd.read_csv(cloud_file)
dat = dat[(dat.cfsirs >= 0) & (dat.cfopaquetsky >= 0)]
dat = dat[dat.cfsirs < 1]

# %%
dat.times = (dat.times - dat.iloc[0].times) / (60 * 60 * 24 * 365.25)

# %%
plt.plot(dat.times, dat.cfsirs, ',')
plt.show()

# %%
plt.hist2d(x=dat.cftottsky, y=dat.cfsirs, bins=30)
plt.colorbar()
plt.show()

# %%
np.corrcoef(x=[dat.cftottsky, dat.cfsirs])
# Out:
# array([[ 1.        ,  0.74464663],
#        [ 0.74464663,  1.        ]])
