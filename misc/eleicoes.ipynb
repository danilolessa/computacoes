# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
import seaborn as sns
sns.set(style="darkgrid")

# %%
nome = []
t = []
votos = []
with open("votos.txt", "r") as fid:
    lines = fid.readlines()
    
    fields = lines[0].split("\t")[1:]
    fields = [f.strip() for f in fields]
    t = [datetime.strptime(field, "%d/%m/%Y") for field in fields]
    
    
    for line in lines[1:]:
        fields = line.split("\t")
        nome.append(fields[0])
        votos.append([float(i) for i in fields[1:]])

# %%
for i in range(0, len(nome)):
    plt.errorbar(t, votos[i], label=nome[i], yerr=3, fmt='-')
plt.legend()
plt.ylim((0, 60))
plt.show()
# Out:
# <img src="data:image/png;base64,...">
