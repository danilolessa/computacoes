# %%
from bs4 import BeautifulSoup as BS
import requests as req

# %%
url = "http://portal.if.usp.br/ifusp/node/893"

# %%
r = req.get(url)

# %%
bs = BS(r.text, "html.parser")

# %%
print(bs.prettify())
# Out:
# <!DOCTYPE html>
# <head>
#  <meta charset="utf-8"/>
#  <meta content="width=device-width" name="viewport"/>
#  <link href="/ifusp/pt-br/node/893" rel="shortlink"/>
#  <link href="/ifusp/pt-br/telefones-%C3%BAteis-no-if" rel="canonical"/>
#  <meta content="Drupal 7 (http://drupal.org)" name="Generator"/>
#  <title>
#   Telefones úteis no IF | Instituto de Física
#  </title>
#  <style media="all" type="text/css">
#   @import url("http://portal.if.usp.br/ifusp/modules/system/system.base.css?o9a7ch");
# @import url("http://portal.if.usp.br/ifusp/modules/system/system.menus.css?o9a7ch");
# @import url("http://portal.if.usp.br/ifusp/modules/system/system.messages.css?o9a7ch");
# @import url("http://portal.if.usp.br/ifusp/modules/system/system.theme.css?o9a7ch");
#  </style>
#  <style media="all" type="text/css">
#   @import url("http://portal.if.usp.br/ifusp/sites/all/modules/ldap/ldap_user/ldap_user.css?o9a7ch");
# ...

# %%
bs.find_all("font")
# Out:
# [<font face="Verdana, Arial, Helvetica, sans-serif" size="2">Visitas ao IF</font>,
#  <font face="Verdana, Arial, Helvetica, sans-serif" size="2">3091-6642</font>,
#  <font face="Verdana, Arial, Helvetica, sans-serif" size="2">Seção de Aluno</font>,
#  <font face="Verdana, Arial, Helvetica, sans-serif" size="2">3091-6924</font>,
#  <font face="Verdana, Arial, Helvetica, sans-serif" size="2">Laboratório Didático</font>,
#  <font face="Verdana, Arial, Helvetica, sans-serif" size="2">3091-7024</font>,
#  <font face="Verdana, Arial, Helvetica, sans-serif" size="2">Comissão de Graduação</font>,
#  <font face="Verdana, Arial, Helvetica, sans-serif" size="2">3091-7159</font>,
#  <font face="Verdana, Arial, Helvetica, sans-serif" size="2">Comissão de Pós-Graduação</font>,
#  <font face="Verdana, Arial, Helvetica, sans-serif" size="2">3091-6901</font>,
#  <font face="Verdana, Arial, Helvetica, sans-serif" size="2">Comissão de Pós-Graduação Interunidades</font>,
# ...
